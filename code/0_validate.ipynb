# %% [markdown]
# # 0. Shapely Validation and Checking Geometry Types

# %% [markdown]
# Two main issues in input data
# - Invalid Geometry
# - Shapes of type Linestring, Multilinestring, Multipolygon and GeometryCollection

# %%
import geopandas as gpd

# %% [markdown]
# Raw data found here https://drive.google.com/drive/folders/1v7xLIkI-Va7H_dUAJ1z9yBJgV3YuYp6T

# %%
buildings=gpd.read_parquet('buildings_berlin.parquet',columns=['geometry'])

# %%
from folium.plugins import MousePosition

# %%
m = buildings[buildings.geom_type=='MultiPolygon'].explore(column=None, popup_columns=['ID'])
MousePosition().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40784f316c1cdf876b6c39184953d32d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40784f316c1cdf876b6c39184953d32d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40784f316c1cdf876b6c39184953d32d = L.map(
#                 &quot;map_40784f316c1cdf876b6c39184953d32d&quot;,
#                 {
#                     center: [52.5135396, 13.287587599999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_40784f316c1cdf876b6c39184953d32d);
#
#
#
#
#
#             var tile_layer_86c5102997176a0cb35ea09932e9f840 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_86c5102997176a0cb35ea09932e9f840.addTo(map_40784f316c1cdf876b6c39184953d32d);
#
#
#             map_40784f316c1cdf876b6c39184953d32d.fitBounds(
#                 [[52.3607656, 13.0188195], [52.6663136, 13.5563557]],
#                 {}
#             );
#
#
#         function geo_json_9358afdfc8c44c689bf2aa25a1ca7817_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9358afdfc8c44c689bf2aa25a1ca7817_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9358afdfc8c44c689bf2aa25a1ca7817_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9358afdfc8c44c689bf2aa25a1ca7817_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9358afdfc8c44c689bf2aa25a1ca7817_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9358afdfc8c44c689bf2aa25a1ca7817.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9358afdfc8c44c689bf2aa25a1ca7817_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9358afdfc8c44c689bf2aa25a1ca7817 = L.geoJson(null, {
#                 onEachFeature: geo_json_9358afdfc8c44c689bf2aa25a1ca7817_onEachFeature,
#
#                 style: geo_json_9358afdfc8c44c689bf2aa25a1ca7817_styler,
#                 pointToLayer: geo_json_9358afdfc8c44c689bf2aa25a1ca7817_pointToLayer,
#                 popupColumns: [&quot;ID&quot;],
#         });
#
#         function geo_json_9358afdfc8c44c689bf2aa25a1ca7817_add (data) {
#             geo_json_9358afdfc8c44c689bf2aa25a1ca7817
#                 .addData(data);
#         }
#             geo_json_9358afdfc8c44c689bf2aa25a1ca7817_add({&quot;bbox&quot;: [13.0188195, 52.3607656, 13.5563557, 52.6663136], &quot;features&quot;: [{&quot;bbox&quot;: [13.4798885, 52.5234685, 13.4810467, 52.5250836], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[13.4809571, 52.5241979], [13.4810134, 52.523838], [13.4801095, 52.5237856], [13.4801093, 52.5237335], [13.4801086, 52.5235173], [13.4800853, 52.5235165], [13.4800822, 52.5234687], [13.4798885, 52.5234685], [13.4798913, 52.5235336], [13.4798936,

# %%
buildings.cx[13.52:13.54,52.42:52.44].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_938c6f9fc00e09b634d1d7cb64745e18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_938c6f9fc00e09b634d1d7cb64745e18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_938c6f9fc00e09b634d1d7cb64745e18 = L.map(
#                 &quot;map_938c6f9fc00e09b634d1d7cb64745e18&quot;,
#                 {
#                     center: [52.43025634999999, 13.530524750000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_938c6f9fc00e09b634d1d7cb64745e18);
#
#
#
#
#
#             var tile_layer_a052fbca8c7d428d689aa0517b190762 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a052fbca8c7d428d689aa0517b190762.addTo(map_938c6f9fc00e09b634d1d7cb64745e18);
#
#
#             map_938c6f9fc00e09b634d1d7cb64745e18.fitBounds(
#                 [[52.4197175, 13.5193916], [52.4407952, 13.5416579]],
#                 {}
#             );
#
#
#         function geo_json_077a3105ef6183679769ab71ccf45411_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_077a3105ef6183679769ab71ccf45411_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_077a3105ef6183679769ab71ccf45411_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_077a3105ef6183679769ab71ccf45411_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_077a3105ef6183679769ab71ccf45411_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_077a3105ef6183679769ab71ccf45411.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_077a3105ef6183679769ab71ccf45411_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_077a3105ef6183679769ab71ccf45411 = L.geoJson(null, {
#                 onEachFeature: geo_json_077a3105ef6183679769ab71ccf45411_onEachFeature,
#
#                 style: geo_json_077a3105ef6183679769ab71ccf45411_styler,
#                 pointToLayer: geo_json_077a3105ef6183679769ab71ccf45411_pointToLayer,
#         });
#
#         function geo_json_077a3105ef6183679769ab71ccf45411_add (data) {
#             geo_json_077a3105ef6183679769ab71ccf45411
#                 .addData(data);
#         }
#             geo_json_077a3105ef6183679769ab71ccf45411_add({&quot;bbox&quot;: [13.5193916, 52.4197175, 13.5416579, 52.4407952], &quot;features&quot;: [{&quot;bbox&quot;: [13.5301483, 52.4305349, 13.5323696, 52.4317461], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.5319324, 52.4311528], [13.5318926, 52.4311784], [13.5318636, 52.4311971], [13.5309771, 52.4317461], [13.5307687, 52.4316187], [13.5303075, 52.4313428], [13.5301483, 52.4312508], [13.5303602, 52.4311186], [13.5310347, 52.4306978], [13.5311096, 52.4306518], [13.531292, 52.4305349], [13.5316647, 52.430756], [13.5314767, 52.4308753], [13.531627, 52.4309735], [13.5317488, 52.431041], [13.5318693, 52.4309661], [13.5321459, 52.4307943], [13.5321865, 52.4307686], [13.5323696, 52.4308793], [13.5319324, 52.4311528]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;588

# %%
buildings = buildings.to_crs(31468)

# %%
buildings.cx[4602104.79012012:4604824.65732128,5810724.070977277:5812978.191857001].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50a8129a212d000af37d2e18d3d00d14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50a8129a212d000af37d2e18d3d00d14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50a8129a212d000af37d2e18d3d00d14 = L.map(
#                 &quot;map_50a8129a212d000af37d2e18d3d00d14&quot;,
#                 {
#                     center: [52.430218, 13.520156549999985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_50a8129a212d000af37d2e18d3d00d14);
#
#
#
#
#
#             var tile_layer_e9ab0abc5ed421ade6d35bbd3dc856b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9ab0abc5ed421ade6d35bbd3dc856b2.addTo(map_50a8129a212d000af37d2e18d3d00d14);
#
#
#             map_50a8129a212d000af37d2e18d3d00d14.fitBounds(
#                 [[52.419611, 13.498655199999986], [52.440825000000004, 13.541657899999986]],
#                 {}
#             );
#
#
#         function geo_json_df3af0c0e0175269fc3a33a3154c8b39_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_df3af0c0e0175269fc3a33a3154c8b39_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_df3af0c0e0175269fc3a33a3154c8b39_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_df3af0c0e0175269fc3a33a3154c8b39_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_df3af0c0e0175269fc3a33a3154c8b39_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_df3af0c0e0175269fc3a33a3154c8b39.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_df3af0c0e0175269fc3a33a3154c8b39_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_df3af0c0e0175269fc3a33a3154c8b39 = L.geoJson(null, {
#                 onEachFeature: geo_json_df3af0c0e0175269fc3a33a3154c8b39_onEachFeature,
#
#                 style: geo_json_df3af0c0e0175269fc3a33a3154c8b39_styler,
#                 pointToLayer: geo_json_df3af0c0e0175269fc3a33a3154c8b39_pointToLayer,
#         });
#
#         function geo_json_df3af0c0e0175269fc3a33a3154c8b39_add (data) {
#             geo_json_df3af0c0e0175269fc3a33a3154c8b39
#                 .addData(data);
#         }
#             geo_json_df3af0c0e0175269fc3a33a3154c8b39_add({&quot;bbox&quot;: [13.498655199999986, 52.419611, 13.541657899999986, 52.440825000000004], &quot;features&quot;: [{&quot;bbox&quot;: [13.530148299999999, 52.4305349, 13.532369599999987, 52.4317461], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.531932399999988, 52.4311528], [13.531892599999985, 52.431178399999986], [13.53186359999999, 52.4311971], [13.530977099999996, 52.4317461], [13.530768699999996, 52.431618699999994], [13.530307499999987, 52.43134280000001], [13.530148299999999, 52.431250799999994], [13.530360199999985, 52.431118600000005], [13.531034699999998, 52.43069779999999], [13.531109599999995, 52.43065180000001], [13.531291999999993, 52.4305349], [13.531664699999995, 52.430755999999995], [13.531476699999995, 52.4308753], [13.531626999999999, 52.430

# %%
buildings
# Out:
#                                                   geometry       ID
# 0        POLYGON ((13.30277 52.51964, 13.30332 52.51964...        0
# 1        POLYGON ((13.35264 52.53331, 13.35276 52.53322...        1
# 2        POLYGON ((13.35397 52.52302, 13.35395 52.52295...        2
# 3        POLYGON ((13.35522 52.52727, 13.35512 52.52739...        3
# 4        POLYGON ((13.36014 52.53152, 13.35987 52.53184...        4
# ...                                                    ...      ...
# 1057114  POLYGON ((13.4585 52.50118, 13.45827 52.50122,...  1057114
# 1057115  POLYGON ((13.11685 52.39058, 13.1174 52.39058,...  1057115
# 1057116  POLYGON ((13.2772 52.53379, 13.27694 52.53323,...  1057116
# 1057117  POLYGON ((13.43921 52.43791, 13.43934 52.43803...  1057117
# 1057118  POLYGON ((13.44577 52.43794, 13.44696 52.43806...  1057118
#
# [1057119 rows x 2 columns]

# %%
# add ID column based on dataframe index
buildings['ID'] = buildings.index

# %%
buildings = buildings.to_crs(31468)

# %% [markdown]
# ## Make valid

# %%
# check validity of geodataframe geometries
valid = buildings.is_valid

# %%
valid.value_counts()
# Out:
# True     1057112
# False          7
# Name: count, dtype: int64

# %%
buildings_valid=buildings.make_valid()

# %%
buildings=gpd.GeoDataFrame({'geometry':buildings_valid})

# %%
buildings
# Out:
#                                                   geometry
# 0        POLYGON ((4588533.734 5821521.726, 4588570.786...
# 1        POLYGON ((4591889.97 5823105.866, 4591898.467 ...
# 2        POLYGON ((4592002.064 5821961.774, 4592000.684...
# 3        POLYGON ((4592077.946 5822437.286, 4592070.997...
# 4        POLYGON ((4592403.073 5822915.869, 4592383.652...
# ...                                                    ...
# 1057114  POLYGON ((4599145.094 5819669.998, 4599129.491...
# 1057115  POLYGON ((4576136.11 5806949.507, 4576173.534 ...
# 1057116  POLYGON ((4586770.205 5823065.392, 4586753.742...
# 1057117  POLYGON ((4597976.059 5812604.354, 4597984.496...
# 1057118  POLYGON ((4598421.808 5812616.361, 4598502.828...
#
# [1057119 rows x 1 columns]

# %% [markdown]
# ## Check Geometry Type

# %%
buildings['geometry'].geom_type.value_counts()
# Out:
# Polygon               1056951
# MultiPolygon               82
# LineString                 49
# MultiLineString            33
# GeometryCollection          4
# Name: count, dtype: int64

# %%
buildings[buildings.geom_type=='MultiPolygon'].explore(column=None, popup_columns=['ID'])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c3bca9c5feb66335f4d6092248a1ccd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c3bca9c5feb66335f4d6092248a1ccd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c3bca9c5feb66335f4d6092248a1ccd = L.map(
#                 &quot;map_6c3bca9c5feb66335f4d6092248a1ccd&quot;,
#                 {
#                     center: [52.52239935, 13.19984894999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6c3bca9c5feb66335f4d6092248a1ccd);
#
#
#
#
#
#             var tile_layer_30ca4d93a5b4ac60eadcbb3ffbeb8b72 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30ca4d93a5b4ac60eadcbb3ffbeb8b72.addTo(map_6c3bca9c5feb66335f4d6092248a1ccd);
#
#
#             map_6c3bca9c5feb66335f4d6092248a1ccd.fitBounds(
#                 [[52.230041, 12.759999999999991], [52.814757699999994, 13.63969789999999]],
#                 {}
#             );
#
#
#         function geo_json_dfdf2c4e228193985255c09c52e9eb76_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_dfdf2c4e228193985255c09c52e9eb76_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_dfdf2c4e228193985255c09c52e9eb76_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_dfdf2c4e228193985255c09c52e9eb76_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_dfdf2c4e228193985255c09c52e9eb76_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_dfdf2c4e228193985255c09c52e9eb76.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_dfdf2c4e228193985255c09c52e9eb76_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_dfdf2c4e228193985255c09c52e9eb76 = L.geoJson(null, {
#                 onEachFeature: geo_json_dfdf2c4e228193985255c09c52e9eb76_onEachFeature,
#
#                 style: geo_json_dfdf2c4e228193985255c09c52e9eb76_styler,
#                 pointToLayer: geo_json_dfdf2c4e228193985255c09c52e9eb76_pointToLayer,
#                 popupColumns: [&quot;ID&quot;],
#         });
#
#         function geo_json_dfdf2c4e228193985255c09c52e9eb76_add (data) {
#             geo_json_dfdf2c4e228193985255c09c52e9eb76
#                 .addData(data);
#         }
#             geo_json_dfdf2c4e228193985255c09c52e9eb76_add({&quot;bbox&quot;: [12.759999999999991, 52.230041, 13.63969789999999, 52.814757699999994], &quot;features&quot;: [{&quot;bbox&quot;: [12.76000389999999, 52.81458209999999, 12.760488299999993, 52.814757699999994], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[12.760078499999986, 52.81474829999999], [12.760079199999995, 52.814755899999994], [12.760087199999994, 52.81475549999998], [12.760086499999993, 52.8147482], [12.760152899999992, 52.81474639999999], [12.760153599999999, 52.814754099999995], [12.760161599999993, 52.8147538], [12.760160899999988, 52.81474619999999], [12.760227299999993, 52.81474469999999], [12.760227899999997, 52.81475209999999], [12.760235799999986, 52.8147519], [12.760235299999996, 52.81474449999

# %% [markdown]
# ### Explode dataframe to turn multipolygons into polygons and remove linestrings

# %%
buildings=buildings.explode(ignore_index=True)
# Out:
# /Users/lisawinkler/opt/anaconda3/envs/py312_uscuni_buildingfootprints/lib/python3.12/site-packages/geopandas/geodataframe.py:2469: FutureWarning: The `drop` keyword argument is deprecated and in future the only supported behaviour will match drop=False. To silence this warning and adopt the future behaviour, stop providing `drop` as a keyword to `set_geometry`. To replicate the `drop=True` behaviour you should update your code to
# `geo_col_name = gdf.active_geometry_name; gdf.set_geometry(new_geo_col).drop(columns=geo_col_name).rename_geometry(geo_col_name)`.
#   return gf.set_geometry(col, drop=drop, inplace=False, crs=crs)

# %%
buildings
# Out:
#                                                   geometry
# 0        POLYGON ((4588533.734 5821521.726, 4588570.786...
# 1        POLYGON ((4591889.97 5823105.866, 4591898.467 ...
# 2        POLYGON ((4592002.064 5821961.774, 4592000.684...
# 3        POLYGON ((4592077.946 5822437.286, 4592070.997...
# 4        POLYGON ((4592403.073 5822915.869, 4592383.652...
# ...                                                    ...
# 1057412  POLYGON ((4599145.094 5819669.998, 4599129.491...
# 1057413  POLYGON ((4576136.11 5806949.507, 4576173.534 ...
# 1057414  POLYGON ((4586770.205 5823065.392, 4586753.742...
# 1057415  POLYGON ((4597976.059 5812604.354, 4597984.496...
# 1057416  POLYGON ((4598421.808 5812616.361, 4598502.828...
#
# [1057417 rows x 1 columns]

# %%
buildings['geometry'].geom_type.value_counts()
# Out:
# Polygon            1057241
# LineString             169
# MultiLineString          4
# MultiPolygon             3
# Name: count, dtype: int64

# %%
buildings=buildings[buildings['geometry'].geom_type=='Polygon']

# %%
buildings['geometry'].geom_type.value_counts()
# Out:
# Polygon    1057241
# Name: count, dtype: int64

# %% [markdown]
# ### Save to parquet

# %%
buildings.to_parquet('buildings_berlin_0.parquet')
